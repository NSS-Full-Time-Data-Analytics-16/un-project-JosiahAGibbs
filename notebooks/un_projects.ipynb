# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gdp_df = pd.read_csv('../data/gdp_percapita.csv')

# %%
gdp_df = gdp_df.drop(columns ='Value Footnotes')

# %%
gdp_df = gdp_df.rename(columns={'Country or Area':'Country', 'Value':'GDP_Per_Capita'})

# %%
gdp_df.columns
# Out:
# Index(['Country', 'Year', 'GDP_Per_Capita'], dtype='object')

# %%
country_count = gdp_df.value_counts('Country').reset_index()

# %%
gdp_df.columns = ['Country', 'Year','GDP_Per_Capita']

# %%
len(country_count.loc[country_count['Value'] == gdp_df.Year.nunique()])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Value'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[406], line 1
# ...

# %%
len(country_count.loc[country_count['Value'] != gdp_df.Year.nunique()])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Value'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[407], line 1
# ...

# %%
total_years = gdp_df['Year'].nunique()
print(total_years)
# Out:
# 34

# %%
gdp_2020 = gdp_df[gdp_df['Year']== 2020]

# %%
print(gdp_2020)
# Out:
#                           Country  Year  GDP_Per_Capita
# 3                     Afghanistan  2020     2769.685745
# 27    Africa Eastern and Southern  2020     3861.111238
# 61     Africa Western and Central  2020     4622.731427
# 95                        Albania  2020    14650.395929
# 129                       Algeria  2020    14194.155748
# ...                           ...   ...             ...
# 8068               Virgin Islands  2020    45055.782930
# 8090           West Bank and Gaza  2020     5423.682547
# 8120                        World  2020    18600.986362
# 8154                       Zambia  2020     3391.595412
# 8188                     Zimbabwe  2020     2987.269823
#
# [247 rows x 3 columns]

# %%
plt.hist(gdp_2020['GDP_Per_Capita'])
# Out:
# (array([111.,  59.,  23.,  23.,  15.,   9.,   3.,   0.,   3.,   1.]),
#  array([   833.92025746,  13576.18426579,  26318.44827412,  39060.71228245,
#          51802.97629078,  64545.24029911,  77287.50430744,  90029.76831577,
#         102772.0323241 , 115514.29633243, 128256.56034076]),
#  <BarContainer object of 10 artists>)

# %%
sns.kdeplot(gdp_2020['GDP_Per_Capita'])
# Out:
# <Axes: xlabel='GDP_Per_Capita', ylabel='Density'>

# %%
sns.boxplot(data = gdp_2020, x='GDP_Per_Capita')
# Out:
# <Axes: xlabel='GDP_Per_Capita'>

# %%
sns.violinplot(x='GDP_Per_Capita', data = gdp_2020)
# Out:
# <Axes: xlabel='GDP_Per_Capita'>

# %%
gdp_2020['GDP_Per_Capita'].median()
# Out:
# 15309.23598817024

# %%
np.median(gdp_2020['GDP_Per_Capita'])
# Out:
# np.float64(15309.23598817024)

# %%
gdp_decades = gdp_df[gdp_df['Year'].isin([1990,2000,2010,2020])]

# %%
sns.boxplot(x='Year', y='GDP_Per_Capita',data=gdp_decades )
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %%
sns.barplot(x='Year', y='GDP_Per_Capita', data= gdp_decades)
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %%
sns.scatterplot(x= 'Year', y='GDP_Per_Capita', data = gdp_decades)
plt.grid(True)

# %%
sns.regplot(x='Year', y='GDP_Per_Capita', data = gdp_decades, line_kws={'color':'red','linewidth':1.5, 'alpha':0.4})
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %%
gdp_df.loc[gdp_df['GDP_Per_Capita'] > 100000].sort_values(by='Year').iloc[0]
# Out:
# Country           United Arab Emirates
# Year                              1990
# GDP_Per_Capita           108057.042464
# Name: 7827, dtype: object

# %%
gdp_df.loc[gdp_df['Year']== 2020].sort_values(by='GDP_Per_Capita').iloc[0]
# Out:
# Country              Burundi
# Year                    2020
# GDP_Per_Capita    833.920257
# Name: 1046, dtype: object

# %%
gdp_burundi=gdp_df[gdp_df['Country'] =='Burundi']
# Out:
#       Country  Year  GDP_Per_Capita
# 1043  Burundi  2023      828.861074
# 1044  Burundi  2022      829.387160
# 1045  Burundi  2021      836.665571
# 1046  Burundi  2020      833.920257
# 1047  Burundi  2019      855.732720
# 1048  Burundi  2018      868.555508
# 1049  Burundi  2017      880.993440
# 1050  Burundi  2016      897.459046
# 1051  Burundi  2015      918.557193
# 1052  Burundi  2014      977.765840
# 1053  Burundi  2013      970.375392
# 1054  Burundi  2012      958.657403
# 1055  Burundi  2011      951.188460
# 1056  Burundi  2010      947.621417
# 1057  Burundi  2009      944.629926
# 1058  Burundi  2008      957.222664
# 1059  Burundi  2007      951.290083
# 1060  Burundi  2006      954.190854
# 1061  Burundi  2005      938.381597
# 1062  Burundi  2004      965.204118
# 1063  Burundi  2003      955.669204
# 1064  Burundi  2002      998.561289
# 1065  Burundi  2001      983.396847
# 1066  Burundi  2000      988.036863
# 1067  Burundi  1999     1017.497778
# ...

# %%
sns.lineplot(x='Year',y='GDP_Per_Capita', data=gdp_burundi)
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %%
gdp_90_20=gdp_df[gdp_df['Year'].isin([1990,2020])]
pivot_gdp=gdp_90_20.pivot(index='Country', columns='Year', values='GDP_Per_Capita').dropna()
difference['Difference']=pivot_gdp[2020]-pivot_gdp[1990]

# %%
internet_df = pd.read_csv('../data/internet_use.csv')

# %%
gdp_and_internet_use.info(), gdp_and_internet_use.describe(), gdp_and_internet_use.head(), gdp_and_internet_use.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9499 entries, 0 to 9498
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             9499 non-null   object
#  1   Year                9499 non-null   object
#  2   GDP_Per_Capita      8219 non-null   float64
#  3   internet_users_pct  6083 non-null   float64
# dtypes: float64(2), object(2)
# memory usage: 297.0+ KB
# (None,
#         GDP_Per_Capita  internet_users_pct
#  count     8219.000000         6083.000000
#  mean     20270.976242           29.655588
#  std      22532.004246           31.381472
#  min        510.822823            0.000000
#  25%       4284.868430            1.497090
#  50%      11916.457927           16.551000
#  75%      28543.305542           55.659950
#  max     174339.077325          100.000000,
#         Country  Year  GDP_Per_Capita  internet_users_pct
# ...

# %%
internet_df.tail(5)
# Out:
#      Country or Area  Year     Value Value Footnotes
# 6078        Zimbabwe  1997  0.033080             NaN
# 6079        Zimbabwe  1996  0.016790             NaN
# 6080        Zimbabwe  1995  0.007684             NaN
# 6081        Zimbabwe  1994  0.001739             NaN
# 6082        Zimbabwe  1990  0.000000             NaN

# %%
internet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6083 entries, 0 to 6082
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country or Area  6083 non-null   object
#  1   Year             6083 non-null   int64
#  2   Value            6083 non-null   float64
#  3   Value Footnotes  2826 non-null   object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 190.2+ KB

# %%
internet_df.describe()
# Out:
#               Year        Value
# count  6083.000000  6083.000000
# mean   2007.207135    29.655588
# std       8.816584    31.381472
# min    1990.000000     0.000000
# 25%    2000.000000     1.497090
# 50%    2007.000000    16.551000
# 75%    2015.000000    55.659950
# max    2023.000000   100.000000

# %%
internet_df=internet_df.drop(columns='Value Footnotes')

# %%
internet_df=internet_df.rename(columns={'Country or Area':'Country','Value':'internet_users_pct'})

# %%
internet_df['Year'].value_counts().sort_index()
# Out:
# Year
# 1990    226
# 1991     39
# 1992     50
# 1993     66
# 1994     92
# 1995    141
# 1996    177
# 1997    188
# 1998    195
# 1999    207
# 2000    210
# 2001    212
# 2002    214
# 2003    208
# 2004    210
# 2005    212
# 2006    212
# 2007    217
# 2008    214
# 2009    214
# 2010    209
# 2011    214
# 2012    209
# 2013    203
# 2014    204
# 2015    203
# 2016    206
# 2017    205
# 2018    174
# 2019    185
# 2020    186
# 2021    186
# 2022    184
# 2023     11
# Name: count, dtype: int64

# %%
internet_df.loc[internet_df['internet_users_pct']>0].sort_values(by='Year').iloc[0]['Year']
# Out:
# np.int64(1990)

# %%
internet_df.loc[internet_df['Year'].isin([2000, 2014])].groupby('Year')['internet_users_pct'].describe()
# Out:
#       count       mean        std   min        25%       50%        75%  \
# Year
# 2000  210.0   9.332385  13.644205  0.00   0.482059   2.88668  10.539025
# 2014  204.0  45.604925  29.295667  0.99  17.403300  46.81800  70.262500
#
#           max
# Year
# 2000  58.6207
# 2014  98.1580

# %%
less_than_5=internet_df.loc[(internet_df['internet_users_pct']<5)]
less_than_5.loc[(less_than_5['Year'] == 2014)]
# Out:
#                                Country  Year  internet_users_pct
# 873                            Burundi  2014             1.04239
# 1033          Central African Republic  2014             2.70000
# 1061                              Chad  2014             2.90000
# 1517  Democratic Republic of the Congo  2014             3.00000
# 1782                           Eritrea  2014             0.99000
# 2451                     Guinea-Bissau  2014             3.32000
# 3364                        Madagascar  2014             3.70000
# 4073                             Niger  2014             1.24868
# 5055                           Somalia  2014             1.63000
# 5116                       South Sudan  2014             2.60000

# %%
internet_df.loc[(internet_df['internet_users_pct'] < 5) & (internet_df['Year'] == 2014)].shape[0]
# Out:
# 10

# %%
gdp_df.dtypes
# Out:
# Country            object
# Year               object
# GDP_Per_Capita    float64
# dtype: object

# %%
internet_df.dtypes
# Out:
# Country                object
# Year                    int64
# internet_users_pct    float64
# dtype: object

# %%
internet_df['Year']=internet_df['Year'].astype(str)

# %%
gdp_and_internet_use= pd.merge(gdp_df,internet_df, on=['Country','Year'], how='outer')

# %%
gdp_and_internet_use.columns
# Out:
# Index(['Country', 'Year', 'GDP_Per_Capita', 'internet_users_pct'], dtype='object')

# %%
gdp_and_internet_use.info(), gdp_and_internet_use.describe(), gdp_and_internet_use.head(), gdp_and_internet_use.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9499 entries, 0 to 9498
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             9499 non-null   object
#  1   Year                9499 non-null   object
#  2   GDP_Per_Capita      8219 non-null   float64
#  3   internet_users_pct  6083 non-null   float64
# dtypes: float64(2), object(2)
# memory usage: 297.0+ KB
# (None,
#         GDP_Per_Capita  internet_users_pct
#  count     8219.000000         6083.000000
#  mean     20270.976242           29.655588
#  std      22532.004246           31.381472
#  min        510.822823            0.000000
#  25%       4284.868430            1.497090
#  50%      11916.457927           16.551000
#  75%      28543.305542           55.659950
#  max     174339.077325          100.000000,
#         Country  Year  GDP_Per_Capita  internet_users_pct
# ...

# %%
gdp_and_internet_use.shape
# Out:
# (9499, 4)

# %%
gdp_and_internet_use.loc[(gdp_and_internet_use['Year'] == '2014')].sort_values(by='internet_users_pct', ascending=False).head(4).dropna()
# Out:
#       Country  Year  GDP_Per_Capita  internet_users_pct
# 3944  Iceland  2014    57981.199448             98.1580
# 824   Bermuda  2014    92298.387811             96.8000
# 6467   Norway  2014    84753.668395             96.3005

# %%
top3countries = gdp_and_internet_use.loc[(gdp_and_internet_use['Year'] == '2014')].sort_values(by='internet_users_pct', ascending=False).head(4).dropna()
grid_data= gdp_and_internet_use[gdp_and_internet_use['Country'].isin(top3countries['Country'])]

# %%
g = sns.FacetGrid(grid_data, col='Country', col_wrap=3, height=4, sharey=False)
g.map_dataframe(sns.lineplot, 'Year', 'GDP_Per_Capita', marker='s').add_legend()
##I give up trying to get the year ticks to simplify...

# %%
gdp_and_internet_use_2014=gdp_and_internet_use.loc[gdp_and_internet_use['Year']=='2014']
# Out:
#                  Country  Year  GDP_Per_Capita  internet_users_pct
# 9361  West Bank and Gaza  2014     5990.426615                 NaN
# 9395               World  2014    17307.606891                 NaN
# 9424               Yemen  2014             NaN             22.5500
# 9455              Zambia  2014     3585.577485              6.5000
# 9489            Zimbabwe  2014     3360.552173             16.3647

# %%
gdp_and_internet_use_2014.plot.scatter(y='internet_users_pct', x = 'GDP_Per_Capita')
# Out:
# <Axes: xlabel='GDP_Per_Capita', ylabel='internet_users_pct'>
